# %% [markdown]
# <a href="https://colab.research.google.com/github/munira-ds/Cat-and-Dog-Image-Classifier/blob/main/Bharat_Intrn_Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Data Science Intrn @bharat intrn
#
# Author:MuniraAkash
#
# Task3: Cat and Dog Image Classifier

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/data (1)', target_size=(64, 64), batch_size=30, class_mode='binary')
# Out:
# Found 1152 images belonging to 2 classes.

# %%
model = Sequential()

model.add(Conv2D(32, (3, 3), input_shape=(64, 64, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(units=128, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(training_set, steps_per_epoch=len(training_set), epochs=30)
# Out:
# Epoch 1/30
# 14/39 [=========>....................] - ETA: 1:23 - loss: 0.7188 - accuracy: 0.4667
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# 39/39 [==============================] - 135s 3s/step - loss: 0.7022 - accuracy: 0.5069
# Epoch 2/30
# 39/39 [==============================] - 18s 474ms/step - loss: 0.6899 - accuracy: 0.5425
# Epoch 3/30
# 39/39 [==============================] - 18s 468ms/step - loss: 0.6699 - accuracy: 0.5946
# Epoch 4/30
# 39/39 [==============================] - 19s 480ms/step - loss: 0.6373 - accuracy: 0.6458
# Epoch 5/30
# 39/39 [==============================] - 19s 483ms/step - loss: 0.6209 - accuracy: 0.6623
# Epoch 6/30
# 39/39 [==============================] - 18s 464ms/step - loss: 0.5992 - accuracy: 0.6823
# Epoch 7/30
# 39/39 [==============================] - 18s 457ms/step - loss: 0.5893 - accuracy: 0.6814
# ...

# %%
model.save('cat_dog_classifier_model1.h5')

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

# %%
new_image_path = 'test_image.jpg'

# %%
new_image_path = '/content/drive/MyDrive/data (1)/cat_test.jpg'

# %%
new_image = image.load_img(new_image_path, target_size=(64, 64))
new_image = image.img_to_array(new_image)
new_image = np.expand_dims(new_image, axis=0)
new_image = new_image / 255.0

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread(new_image_path )

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
prediction = model.predict(new_image)
# Out:
# 1/1 [==============================] - 0s 128ms/step

# %%
if prediction[0][0] == 1:
    print("Dog")
else:
    print("Cat")
# Out:
# Cat

# %%
new_image_path = '/content/drive/MyDrive/data (1)/dog_test2.jpg'

# %%
new_image = image.load_img(new_image_path, target_size=(64, 64))
new_image = image.img_to_array(new_image)
new_image = np.expand_dims(new_image, axis=0)
new_image = new_image / 255.0

# %%
img = mpimg.imread(new_image_path )

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
prediction = model.predict(new_image)
# Out:
# 1/1 [==============================] - 0s 22ms/step

# %%
if prediction[0] == 0:
    print("Cat")
else:
    print("Dog")
# Out:
# Dog
